# %% [markdown]
# # 8.2. Training a Convnet from scratch on a small dataset
# - The dataset contains 25000 images of dogs and cats (12,500 for each class). We will create a new dataset containing 3 subsets:
#     - Training set with 1000 samples of each class.
#     - Validation set with 500 samples of each class.
#     - Test set with 1000 samples of each class.
# - Having more dataset will make the problem easier also cost a lot of computational power.

# %%
# !rm -rf convnet_from_scratch.keras train cats_vs_dogs_small test1
# Out:
# /bin/bash: /opt/conda/lib/libtinfo.so.6: no version information available (required by /bin/bash)

# %%
# import libraries
import os
import zipfile
import pandas as pd
import os, shutil, pathlib
import matplotlib.pyplot as plt

# import TF
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.utils import image_dataset_from_directory

# %% [markdown]
# ## 8.2.1. Download Dataset

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/dogs-vs-cats/test1.zip
# /kaggle/input/dogs-vs-cats/train.zip
# /kaggle/input/dogs-vs-cats/sampleSubmission.csv

# %%
with zipfile.ZipFile("../input/dogs-vs-cats/train.zip","r") as z:
    z.extractall(".")
    z.close()
    
with zipfile.ZipFile("../input/dogs-vs-cats/test1.zip","r") as z:
    z.extractall(".")
    z.close()

# %%
# !ls
# Out:
# /bin/bash: /opt/conda/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# __notebook__.ipynb  test1  train

# %% [markdown]
# ### Copy images to training, validation, and test directories

# %%
# set paths
original_dir = pathlib.Path("train")
new_base_dir = pathlib.Path("cats_vs_dogs_small")

# %%
def make_subset(subset_name, start_index, end_index):
    for category in ("cat", "dog"):
        dir = new_base_dir / subset_name / category
        os.makedirs(dir)
        fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
        for fname in fnames:
            shutil.copyfile(src=original_dir / fname, dst=dir / fname)

# %%
make_subset("train", start_index=0, end_index=1000)
make_subset("validation", start_index=1000, end_index=1500)
make_subset("test", start_index=1500, end_index=2500)

# %%
# !ls cats_vs_dogs_small/
# Out:
# /bin/bash: /opt/conda/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# test  train  validation

# %% [markdown]
# ## 8.2.2. Build model
# - We will still use the architecture Convnet as MNIST but we will add Conv2D and MaxPooling2D to further reduce the feature maps in the Flatten layer. Here, the size of the feature maps decrease from 180x180 to 7x7while the depth of the feature map increase from 32 to 256. As we are doing binary classification, we will use `sigmoid` activation function.
# - We will rescalre the image range from [0, 255] to [0, 1].

# %%
# build model
inputs = keras.Input(shape=(180, 180, 3))

x = layers.Rescaling(1./255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Flatten()(x)

outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 178, 178, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 89, 89, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 41, 41, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 18, 18, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 9, 9, 256)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 7, 7, 256)         590080
#
#  max_pooling2d_4 (MaxPooling  (None, 3, 3, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 1)                 2305
#
# =================================================================
# Total params: 980,801
# Trainable params: 980,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile model
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %% [markdown]
# ## 8.2.3. Data Preprocessing
# - We need to process it into tensor.
#     - Read picture file.
#     - Decode JPEG into RGB grids of pixels.
#     - Convert these into floating-point tensors.
#     - Resize them to a same size (180x180).
#     - Pack them into batches (32 images / batch).
# - By using the function `image_dataset_from_directory()` we can get the Dataset object which is an iterator. We can use it in a for loop and it will return the batch of input data and labels. The assumption here is that each folder contains images from one of our class. It will then index the image files in each subdirectory. Finally, it will create and return a `tf.data.Dataset` object configured to each these files, shuffle them, decode them to tensors, resize them to a shared size and pack them into batches.

# %%
train_dataset = image_dataset_from_directory(
    new_base_dir / "train",
    image_size=(180, 180),
    batch_size=32)
validation_dataset = image_dataset_from_directory(
    new_base_dir / "validation",
    image_size=(180, 180),
    batch_size=32)
test_dataset = image_dataset_from_directory(
    new_base_dir / "test",
    image_size=(180, 180),
    batch_size=32)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 2000 files belonging to 2 classes.

# %%
# check dataset
for data_batch, label_batch in train_dataset:
    print(data_batch.shape)
    print(label_batch.shape)
    break
# Out:
# (32, 180, 180, 3)
# (32,)

# %% [markdown]
# ### Model Checkpoint callback
# - Save the model after each epoch. This way guarantees that your saved file will always contain the state of the model corresponding to its best performing training epoch, in terms of its performance on the validation data.
# - By then, we don't have to retrain a new model for a lower number of epochs if we start overfitting: we can just reload our saved file

# %%
# set up call backs
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_loss"
    )
]

# train model
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks
)
# Out:
# Epoch 1/30
# 63/63 [==============================] - 11s 63ms/step - loss: 0.7199 - accuracy: 0.5255 - val_loss: 0.6992 - val_accuracy: 0.5000
# Epoch 2/30
# 63/63 [==============================] - 4s 62ms/step - loss: 0.6843 - accuracy: 0.5860 - val_loss: 0.6854 - val_accuracy: 0.5400
# Epoch 3/30
# 63/63 [==============================] - 4s 57ms/step - loss: 0.6454 - accuracy: 0.6360 - val_loss: 0.6600 - val_accuracy: 0.6030
# Epoch 4/30
# 63/63 [==============================] - 4s 57ms/step - loss: 0.5841 - accuracy: 0.6770 - val_loss: 0.6045 - val_accuracy: 0.6680
# Epoch 5/30
# 63/63 [==============================] - 4s 63ms/step - loss: 0.5495 - accuracy: 0.7280 - val_loss: 0.7546 - val_accuracy: 0.6370
# Epoch 6/30
# 63/63 [==============================] - 5s 70ms/step - loss: 0.5065 - accuracy: 0.7445 - val_loss: 0.6413 - val_accuracy: 0.6920
# Epoch 7/30
# 63/63 [==============================] - 4s 62ms/step - loss: 0.4577 - accuracy: 0.7795 - val_loss: 0.6568 - val_accuracy: 0.6800
# Epoch 8/30
# 63/63 [==============================] - 4s 56ms/step - loss: 0.3944 - accuracy: 0.8255 - val_loss: 0.7711 - val_accuracy: 0.6500
# Epoch 9/30
# 63/63 [==============================] - 4s 60ms/step - loss: 0.3478 - accuracy: 0.8450 - val_loss: 0.6578 - val_accuracy: 0.7140
# Epoch 10/30
# 63/63 [==============================] - 4s 56ms/step - loss: 0.2685 - accuracy: 0.8850 - val_loss: 0.8311 - val_accuracy: 0.6930
# Epoch 11/30
# 63/63 [==============================] - 4s 55ms/step - loss: 0.2251 - accuracy: 0.9010 - val_loss: 0.8513 - val_accuracy: 0.6850
# Epoch 12/30
# 63/63 [==============================] - 4s 59ms/step - loss: 0.1710 - accuracy: 0.9310 - val_loss: 0.8962 - val_accuracy: 0.6780
# Epoch 13/30
# 63/63 [==============================] - 4s 56ms/step - loss: 0.1297 - accuracy: 0.9475 - val_loss: 1.0245 - val_accuracy: 0.7280
# Epoch 14/30
# 63/63 [==============================] - 4s 60ms/step - loss: 0.1100 - accuracy: 0.9615 - val_loss: 1.1911 - val_accuracy: 0.6920
# Epoch 15/30
# 63/63 [==============================] - 4s 56ms/step - loss: 0.0959 - accuracy: 0.9675 - val_loss: 1.2210 - val_accuracy: 0.7090
# Epoch 16/30
# 63/63 [==============================] - 4s 56ms/step - loss: 0.0701 - accuracy: 0.9745 - val_loss: 1.4102 - val_accuracy: 0.7150
# Epoch 17/30
# 63/63 [==============================] - 4s 61ms/step - loss: 0.0653 - accuracy: 0.9760 - val_loss: 1.4915 - val_accuracy: 0.7180
# Epoch 18/30
# 63/63 [==============================] - 4s 57ms/step - loss: 0.0682 - accuracy: 0.9785 - val_loss: 1.4956 - val_accuracy: 0.6900
# Epoch 19/30
# 63/63 [==============================] - 4s 61ms/step - loss: 0.0450 - accuracy: 0.9855 - val_loss: 1.7032 - val_accuracy: 0.7010
# Epoch 20/30
# 63/63 [==============================] - 4s 68ms/step - loss: 0.0597 - accuracy: 0.9785 - val_loss: 1.6930 - val_accuracy: 0.7060
# Epoch 21/30
# 63/63 [==============================] - 4s 57ms/step - loss: 0.0677 - accuracy: 0.9840 - val_loss: 1.7125 - val_accuracy: 0.7130
# Epoch 22/30
# 63/63 [==============================] - 4s 61ms/step - loss: 0.0436 - accuracy: 0.9855 - val_loss: 1.9234 - val_accuracy: 0.7120
# Epoch 23/30
# 63/63 [==============================] - 4s 55ms/step - loss: 0.0482 - accuracy: 0.9830 - val_loss: 2.2679 - val_accuracy: 0.7210
# Epoch 24/30
# 63/63 [==============================] - 4s 56ms/step - loss: 0.0507 - accuracy: 0.9825 - val_loss: 2.2780 - val_accuracy: 0.6820
# Epoch 25/30
# 63/63 [==============================] - 4s 57ms/step - loss: 0.0463 - accuracy: 0.9840 - val_loss: 2.0551 - val_accuracy: 0.7000
# Epoch 26/30
# 63/63 [==============================] - 4s 56ms/step - loss: 0.0586 - accuracy: 0.9815 - val_loss: 2.1399 - val_accuracy: 0.6960
# Epoch 27/30
# 63/63 [==============================] - 4s 59ms/step - loss: 0.0471 - accuracy: 0.9885 - val_loss: 2.3471 - val_accuracy: 0.6860
# Epoch 28/30
# 63/63 [==============================] - 4s 66ms/step - loss: 0.0377 - accuracy: 0.9860 - val_loss: 2.1719 - val_accuracy: 0.6940
# Epoch 29/30
# 63/63 [==============================] - 4s 56ms/step - loss: 0.0471 - accuracy: 0.9905 - val_loss: 2.3501 - val_accuracy: 0.6910
# Epoch 30/30
# 63/63 [==============================] - 4s 57ms/step - loss: 0.0562 - accuracy: 0.9875 - val_loss: 2.9790 - val_accuracy: 0.6750

# %% [markdown]
# ### Display curves of loss and accuracy during training

# %%
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# **Note**: the plots are overfit. The training accuracy increases linearly over time till it is 100%, while the validation accuracy is 75% peak. The validation loss stall after 10 epochs while the training loss keep decreasing.

# %% [markdown]
# ### Evaluate the model on testset

# %%
test_model = keras.models.load_model("convnet_from_scratch.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 63/63 [==============================] - 2s 31ms/step - loss: 0.6128 - accuracy: 0.6815
# Test accuracy: 0.682

# %% [markdown]
# **Note**: now overfit will be our concern. We can keep pushing the limit by using regularization: dropout or weight decay (L2). However, we can also use data augmentation.

# %% [markdown]
# ## 8.2.4. Data Augmentation
# - In our case, since the model is relatively larger than the dataset, aka we don't have enough data. Thus overfit happens.
# - Data augmentation randomly transform the image to a believable-looking images.
# - Goal, at the training time, the model will never see the same exact picture twice. This helps expose the model to more aspects of the data so it can generalize better.

# %%
# add data augmenntation layers - to all images
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"), 
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

# %% [markdown]
# ### Display some randomly augmented training image

# %%
plt.figure(figsize=(10,10))

for images, _ in train_dataset.take(1):  # sample 1 batch, same as "break" the loop
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i+1)
        
        # display the first image of the batch
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %% [markdown]
# **Note**:
# - The inputs the model sees are still heavily intercorrelated as they come from a small number of original images. We can't proudce new info; we can only mixing existing info.
# - Similar as Dropout layer, data augmentation layer is inactive during calls of predict() or evaluate().

# %%
# build model
inputs = keras.Input(shape=(180, 180, 3))

x = data_augmentation(inputs)
x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)

outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  sequential (Sequential)     (None, 180, 180, 3)       0
#
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_5 (Conv2D)           (None, 178, 178, 32)      896
#
#  max_pooling2d_5 (MaxPooling  (None, 89, 89, 32)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_6 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 41, 41, 128)       73856
#
#  max_pooling2d_7 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 18, 18, 256)       295168
#
#  max_pooling2d_8 (MaxPooling  (None, 9, 9, 256)        0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 7, 7, 256)         590080
#
#  max_pooling2d_9 (MaxPooling  (None, 3, 3, 256)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 2304)              0
#
#  dropout (Dropout)           (None, 2304)              0
#
#  dense_1 (Dense)             (None, 1)                 2305
#
# =================================================================
# Total params: 980,801
# Trainable params: 980,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile model
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %%
# set up call backs
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch_with_augmentation.keras",
        save_best_only=True,
        monitor="val_loss"
    )
]

# train model
history = model.fit(
    train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 63/63 [==============================] - 7s 90ms/step - loss: 0.6990 - accuracy: 0.5080 - val_loss: 0.6920 - val_accuracy: 0.5280
# Epoch 2/100
# 63/63 [==============================] - 5s 77ms/step - loss: 0.6922 - accuracy: 0.5435 - val_loss: 0.6859 - val_accuracy: 0.5360
# Epoch 3/100
# 63/63 [==============================] - 6s 81ms/step - loss: 0.6862 - accuracy: 0.5555 - val_loss: 0.6708 - val_accuracy: 0.5740
# Epoch 4/100
# 63/63 [==============================] - 5s 77ms/step - loss: 0.6804 - accuracy: 0.5845 - val_loss: 0.6567 - val_accuracy: 0.6240
# Epoch 5/100
# 63/63 [==============================] - 5s 80ms/step - loss: 0.6534 - accuracy: 0.6260 - val_loss: 0.6779 - val_accuracy: 0.5900
# Epoch 6/100
# 63/63 [==============================] - 5s 76ms/step - loss: 0.6424 - accuracy: 0.6350 - val_loss: 0.6494 - val_accuracy: 0.6010
# Epoch 7/100
# 63/63 [==============================] - 5s 81ms/step - loss: 0.6228 - accuracy: 0.6535 - val_loss: 0.5970 - val_accuracy: 0.6800
# Epoch 8/100
# 63/63 [==============================] - 6s 85ms/step - loss: 0.6138 - accuracy: 0.6665 - val_loss: 0.6027 - val_accuracy: 0.6870
# Epoch 9/100
# 63/63 [==============================] - 5s 75ms/step - loss: 0.5890 - accuracy: 0.6990 - val_loss: 0.5825 - val_accuracy: 0.6920
# Epoch 10/100
# 63/63 [==============================] - 5s 80ms/step - loss: 0.5931 - accuracy: 0.6880 - val_loss: 0.5582 - val_accuracy: 0.6890
# Epoch 11/100
# 63/63 [==============================] - 6s 83ms/step - loss: 0.5862 - accuracy: 0.6950 - val_loss: 0.6714 - val_accuracy: 0.6560
# Epoch 12/100
# 63/63 [==============================] - 6s 87ms/step - loss: 0.6016 - accuracy: 0.6855 - val_loss: 0.5308 - val_accuracy: 0.7230
# Epoch 13/100
# 63/63 [==============================] - 5s 80ms/step - loss: 0.5536 - accuracy: 0.7250 - val_loss: 0.5502 - val_accuracy: 0.7270
# Epoch 14/100
# 63/63 [==============================] - 5s 76ms/step - loss: 0.5689 - accuracy: 0.7130 - val_loss: 0.6335 - val_accuracy: 0.6590
# Epoch 15/100
# 63/63 [==============================] - 5s 76ms/step - loss: 0.5317 - accuracy: 0.7315 - val_loss: 0.6187 - val_accuracy: 0.6840
# Epoch 16/100
# 63/63 [==============================] - 5s 75ms/step - loss: 0.5481 - accuracy: 0.7265 - val_loss: 0.5135 - val_accuracy: 0.7470
# Epoch 17/100
# 63/63 [==============================] - 6s 85ms/step - loss: 0.5241 - accuracy: 0.7450 - val_loss: 0.4879 - val_accuracy: 0.7650
# Epoch 18/100
# 63/63 [==============================] - 5s 79ms/step - loss: 0
100
# 63/63 [==============================] - 5s 75ms/step - loss: 0.1911 - accuracy: 0.9230 - val_loss: 0.5649 - val_accuracy: 0.8400
# Epoch 77/100
# 63/63 [==============================] - 5s 79ms/step - loss: 0.2436 - accuracy: 0.9080 - val_loss: 0.5579 - val_accuracy: 0.8610
# Epoch 78/100
# 63/63 [==============================] - 5s 75ms/step - loss: 0.2051 - accuracy: 0.9155 - val_loss: 0.6021 - val_accuracy: 0.8710
# Epoch 79/100
# 63/63 [==============================] - 6s 99ms/step - loss: 0.2300 - accuracy: 0.9160 - val_loss: 0.5924 - val_accuracy: 0.8520
# Epoch 80/100
# 63/63 [==============================] - 5s 75ms/step - loss: 0.2383 - accuracy: 0.9055 - val_loss: 0.4759 - val_accuracy: 0.8720
# Epoch 81/100
# 63/63 [==============================] - 5s 80ms/step - loss: 0.2151 - accuracy: 0.9135 - val_loss: 0.6133 - val_accuracy: 0.8430
# Epoch 82/100
# 63/63 [==============================] - 5s 75ms/step - loss: 0.1949 - accuracy: 0.9220 - val_loss: 0.7142 - val_accuracy: 0.8380
# Epoch 83/100
# 63/63 [==============================] - 5s 74ms/step - loss: 0.2078 - accuracy: 0.9155 - val_loss: 0.5234 - val_accuracy: 0.8470
# Epoch 84/100
# 63/63 [==============================] - 6s 84ms/step - loss: 0.2280 - accuracy: 0.9165 - val_loss: 0.8906 - val_accuracy: 0.7880
# Epoch 85/100
# 63/63 [==============================] - 5s 79ms/step - loss: 0.2019 - accuracy: 0.9175 - val_loss: 1.0105 - val_accuracy: 0.8060
# Epoch 86/100
# 63/63 [==============================] - 5s 80ms/step - loss: 0.2058 - accuracy: 0.9195 - val_loss: 0.6836 - val_accuracy: 0.8600
# Epoch 87/100
# 63/63 [==============================] - 5s 80ms/step - loss: 0.2061 - accuracy: 0.9235 - val_loss: 0.4857 - val_accuracy: 0.8620
# Epoch 88/100
# 63/63 [==============================] - 5s 79ms/step - loss: 0.2244 - accuracy: 0.9180 - val_loss: 0.6118 - val_accuracy: 0.8470
# Epoch 89/100
# 63/63 [==============================] - 5s 76ms/step - loss: 0.2135 - accuracy: 0.9275 - val_loss: 0.7154 - val_accuracy: 0.8350
# Epoch 90/100
# 63/63 [==============================] - 5s 80ms/step - loss: 0.2096 - accuracy: 0.9200 - val_loss: 0.5522 - val_accuracy: 0.8590
# Epoch 91/100
# 63/63 [==============================] - 5s 84ms/step - loss: 0.1875 - accuracy: 0.9250 - val_loss: 0.7941 - val_accuracy: 0.8280
# Epoch 92/100
# 63/63 [==============================] - 5s 76ms/step - loss: 0.2031 - accuracy: 0.9260 - val_loss: 0.6303 - val_accuracy: 0.8480
# Epoch 93/100
# 63/63 [==============================] - 5s 80ms/step - loss: 0.1728 - accuracy: 0.9335 - val_loss: 0.7574 - val_accuracy: 0.8350
# Epoch 94/100
# 63/63 [==============================] - 5s 75ms/step - loss: 0.2011 - accuracy: 0.9290 - val_loss: 0.7264 - val_accuracy: 0.8290
# Epoch 95/100
# 63/63 [==============================] - 5s 78ms/step - loss: 0.2138 - accuracy: 0.9220 - val_loss: 0.6499 - val_accuracy: 0.8350
# Epoch 96/100
# 63/63 [==============================] - 7s 104ms/step - loss: 0.1643 - accuracy: 0.9415 - val_loss: 0.9827 - val_accuracy: 0.8030
# Epoch 97/100
# 63/63 [==============================] - 5s 78ms/step - loss: 0.2161 - accuracy: 0.9200 - val_loss: 0.6966 - val_accuracy: 0.8490
# Epoch 98/100
# 63/63 [==============================] - 5s 78ms/step - loss: 0.2055 - accuracy: 0.9240 - val_loss: 0.6187 - val_accuracy: 0.8060
# Epoch 99/100
# 63/63 [==============================] - 5s 80ms/step - loss: 0.1885 - accuracy: 0.9325 - val_loss: 0.6148 - val_accuracy: 0.8260
# Epoch 100/100
# 63/63 [==============================] - 7s 100ms/step - loss: 0.2027 - accuracy: 0.9245 - val_loss: 0.6761 - val_accuracy: 0.7830

# %% [markdown]
# **Note**: Thanks for data augmentation and dropout, the model overfit much later. This means that the validation loss and accuracy curves are closer to the training ones at a lower and higher rate respectively. Our model generalized well!

# %%
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# ### Evaluate on testset

# %%
test_model = keras.models.load_model("convnet_from_scratch_with_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 63/63 [==============================] - 3s 36ms/step - loss: 0.4405 - accuracy: 0.8275
# Test accuracy: 0.827
